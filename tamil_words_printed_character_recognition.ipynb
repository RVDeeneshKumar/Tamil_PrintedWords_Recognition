# %%
# !pip install easyocr --no-deps # Colab already has all dependencies
# Out:
# ...
#      |████████████████████████████████| 63.6 MB 1.5 MB/s
# ...

# %%
# !pip install python-bidi
# Out:
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# easyocr 1.4.1 requires opencv-python-headless, which is not installed.
# ...

# %% [markdown]
# ## Download Tamil Image

# %%
! wget --output-document=ta_poster.jpg https://images-na.ssl-images-amazon.com/images/I/81DxM9YrnxL.jpg
# Out:
# --2021-01-27 06:57:06--  https://images-na.ssl-images-amazon.com/images/I/81DxM9YrnxL.jpg
# Resolving images-na.ssl-images-amazon.com (images-na.ssl-images-amazon.com)... 151.101.1.16, 151.101.65.16, 151.101.129.16, ...
# Connecting to images-na.ssl-images-amazon.com (images-na.ssl-images-amazon.com)|151.101.1.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 460350 (450K) [image/jpeg]
# Saving to: ‘ta_poster.jpg’
#
# ta_poster.jpg       100%[===================>] 449.56K  --.-KB/s    in 0.01s
#
# 2021-01-27 06:57:06 (32.2 MB/s) - ‘ta_poster.jpg’ saved [460350/460350]

# %% [markdown]
# ## Display Tamil Image

# %%
# show an image
import PIL
from PIL import ImageDraw
im = PIL.Image.open("Thamizh Thaai Vaazhthu.jpg")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=292x1712 at 0x7FE05948F550>

# %% [markdown]
# ### Download Tamil and English Models

# %%
# Create a reader to do OCR.
# If you change to GPU instance, it will be faster. But CPU is enough.
# (by MENU > Runtime > Change runtime type > GPU, then redo from beginning )
import easyocr
reader = easyocr.Reader(['ta','en'])

# %% [markdown]
# ## Perform OCR and extract Bounding Boxes

# %%
# Doing OCR. Get bounding boxes.
bounds = reader.readtext('Thamizh Thaai Vaazhthu.jpg')
bounds
# Out:
# [([[136, 10], [194, 10], [194, 34], [136, 34]], 'Tamil', 0.6593954164732752),
#  ([[40, 84], [262, 84], [262, 114], [40, 114]],
#   'நீராருங் கடலுடுத்த',
#   0.7544739670587571),
#  ([[39, 117], [206, 117], [206, 147], [39, 147]],
#   'நிலமடந்தைக்',
#   0.7745853167456815),
#  ([[40, 152], [228, 152], [228, 182], [40, 182]],
#   'கெழிலொழுகும்',
#   0.7417841862812357),
#  ([[39, 183], [286, 183], [286, 214], [39, 214]],
#   'சீராரும் வதனமெனத்',
#   0.5564812645942799),
#  ([[40, 219], [180, 219], [180, 250], [40, 250]],
#   'திகழ் பரதக்',
#   0.9015843506302434),
#  ([[39, 252], [186, 252], [186, 282], [39, 282]],
#   'கண்டமிதில்',
#   0.9492080961796983),
#  ([[42, 285], [199, 285], [199, 313], [42, 313]],
#   'தெக்கணமும்',
#   0.9179593122530548),
#  ([[42, 320], [188, 320], [188, 352], [42, 352]],
#   'அதிற்சிறந்த',
#   0.8312118406852427),
#  ([[40, 354], [178, 354], [178, 380], [40, 380]],
#   'திராவிடநல்',
#   0.7518466329508492),
# ...

# %% [markdown]
# ### Draw the extracted Bounding boxes

# %%
# Draw bounding boxes
def draw_boxes(image, bounds, color='blue', width=2):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return image

draw_boxes(im, bounds)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=292x1712 at 0x7FE05948F550>
